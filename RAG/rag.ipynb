# %% [markdown]
# # CosmosDB for NoSQL RAG
# <img src = "./cosmosdbrag.png">

# %% [markdown]
# ### Installing important packages and libraries

# %%
# %pip install azure-cosmos
# %pip install openai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\dilmurodm\Desktop\Semantic_Kernel\semantic_kernel\venv_py313\Scripts\python.exe: No module named pip
# Note: you may need to restart the kernel to use updated packages.
# c:\Users\dilmurodm\Desktop\Semantic_Kernel\semantic_kernel\venv_py313\Scripts\python.exe: No module named pip

# %%
from azure.cosmos import CosmosClient, PartitionKey, exceptions
import os
import json
from dotenv import load_dotenv

load_dotenv()

# Set OpenAI API version for Azure AI Projects compatibility
if not os.getenv("OPENAI_API_VERSION"):
    os.environ["OPENAI_API_VERSION"] = "2024-10-01-preview"
    print(f"Set OPENAI_API_VERSION to {os.environ['OPENAI_API_VERSION']}")
else:
    print(f"Using existing OPENAI_API_VERSION: {os.environ['OPENAI_API_VERSION']}")
# Out:
# Using existing OPENAI_API_VERSION: 2024-10-01-preview

# %% [markdown]
# ### Creating a connection to CosmosDB via connection string
# and creating a database if it doesn't exist

# %%
cosmosdb_connection_string = os.getenv("COSMOS_DB_CONNECTION_STRING")

if cosmosdb_connection_string is None:
    raise ValueError("COSMOSDB_CONNECTION_STRING environment variable is not set.")
client = CosmosClient.from_connection_string(cosmosdb_connection_string)
database_name = os.getenv("DATABASE_NAME")

database = client.create_database_if_not_exists(id=database_name)

# %% [markdown]
# ### Defining the vector embedding policy

# %%
pk = "/category"

vector_embedding_policy = {
    "vectorEmbeddings": [
        {
            "path":"/vector",
            "dataType":"float32",
            "distanceFunction":"cosine",
            "dimensions":1536
        }
    ]
}

# %% [markdown]
# ### Creating a vector index with diskANN algorithm

# %%
indexing_policy = {
    "vectorIndexes": [
        {
            "path":"/vector",
            "type":"diskANN"
        }

    ]
}

# %% [markdown]
# ### Creating container inside of the database

# %%
try:
    container_name = os.getenv("CONTAINER_NAME")
    
    container = database.create_container_if_not_exists(
        id=container_name,
        partition_key=PartitionKey(path=pk),
        indexing_policy=indexing_policy,
        vector_embedding_policy=vector_embedding_policy
        
    )
    
except Exception as e:
    print(e)

# %% [markdown]
# ### Creating Azure OpenAI Client

# %%
from azure.identity import DefaultAzureCredential

azure_openai_endpoint = os.getenv("AZURE_OPENAI_ENDPOINT")  
azure_openai_key = os.getenv("AZURE_OPENAI_KEY")

# Check if this is an Azure AI Foundry endpoint
is_ai_foundry = "ai.azure.com" in azure_openai_endpoint or "services.ai.azure.com" in azure_openai_endpoint

if is_ai_foundry:
    # Use Azure AI Projects client for AI Foundry
    print("Detected Azure AI Foundry endpoint - using Azure AI Projects client")
    try:
        from azure.ai.projects import AIProjectClient
        
        credential = DefaultAzureCredential()
        project_client = AIProjectClient(
            endpoint=azure_openai_endpoint,
            credential=credential
        )
        
        # Get the OpenAI client from the project client
        azure_openai_client = project_client.get_openai_client()
        print("Using Azure AI Projects client for AI Foundry")
        
    except ImportError:
        print("Azure AI Projects package not installed. Installing...")
        import subprocess
        import sys
        subprocess.check_call([sys.executable, "-m", "pip", "install", "azure-ai-projects"])
        
        from azure.ai.projects import AIProjectClient
        credential = DefaultAzureCredential()
        project_client = AIProjectClient(
            endpoint=azure_openai_endpoint,
            credential=credential
        )
        azure_openai_client = project_client.get_openai_client()
        print("Installed and configured Azure AI Projects client")
        
    except Exception as e:
        print(f"Azure AI Projects client failed: {e}")
        raise e
else:
    # Use standard Azure OpenAI client for regular endpoints
    from openai import AzureOpenAI
    
    if azure_openai_key:
        azure_openai_client = AzureOpenAI(
            api_version="2024-06-01",
            api_key=azure_openai_key,
            azure_endpoint=azure_openai_endpoint
        )
        print("Using API key authentication")
    else:
        from azure.identity import get_bearer_token_provider
        
        credential = DefaultAzureCredential()
        token_provider = get_bearer_token_provider(credential, "https://cognitiveservices.azure.com/.default")
        
        azure_openai_client = AzureOpenAI(
            api_version="2024-06-01",
            azure_ad_token_provider=token_provider,
            azure_endpoint=azure_openai_endpoint
        )
        print("Using Azure AD authentication")
# Out:
# Detected Azure AI Foundry endpoint - using Azure AI Projects client
# Using Azure AI Projects client for AI Foundry
# Using Azure AI Projects client for AI Foundry

# %% [markdown]
# ### Creating Embedding Generation Function
# embedding engine to be used: text-embedding-ada-002
# <br>
# vector dimensions: 1536

# %%
def generate_embeddings(client, text):
    """
    Generate embeddings for the given text using Azure OpenAI.
    
    Args:
        client: Azure OpenAI client
        text: Text to generate embeddings for
        
    Returns:
        List of embedding values
    """
    embedding_model = os.getenv("EMBEDDING_ENGINE")
    
    if not embedding_model:
        raise ValueError("EMBEDDING_ENGINE environment variable is not set")
    
    if not text or not isinstance(text, str):
        raise ValueError("Text input must be a non-empty string")
    
    try:
        # Limit text length to avoid token limits (typically 8192 tokens for ada-002)
        max_text_length = 8000  # Conservative limit
        if len(text) > max_text_length:
            text = text[:max_text_length]
            print(f"Text truncated to {max_text_length} characters")
        
        response = client.embeddings.create(
            input=text,
            model=embedding_model
        )
        
        embeddings = response.model_dump()
        return embeddings['data'][0]['embedding']
        
    except Exception as e:
        print(f" Error generating embeddings: {e}")
        print(f" Text length: {len(text)}")
        print(f" Model: {embedding_model}")
        raise e

# %% [markdown]
# ### Loading food dataset
# the food dataset is stored in `"./fooditems.json"`
# <br>
# we will generate vector embedding for the `/description` field of each food object and store it in a new field `/vector`

# %%
# Validate environment variables before processing
print("🔍 Environment Variables Check:")
print(f"   COSMOS_DB_CONNECTION_STRING: {'✅ Set' if os.getenv('COSMOS_DB_CONNECTION_STRING') else '❌ Missing'}")
print(f"   DATABASE_NAME: {os.getenv('DATABASE_NAME') or '❌ Missing'}")
print(f"   CONTAINER_NAME: {os.getenv('CONTAINER_NAME') or '❌ Missing'}")
print(f"   AZURE_OPENAI_ENDPOINT: {os.getenv('AZURE_OPENAI_ENDPOINT') or '❌ Missing'}")
print(f"   AZURE_OPENAI_KEY: {'✅ Set' if os.getenv('AZURE_OPENAI_KEY') else '❌ Missing'}")
print(f"   EMBEDDING_ENGINE: {os.getenv('EMBEDDING_ENGINE') or '❌ Missing'}")
print(f"   GPT_ENGINE: {os.getenv('GPT_ENGINE') or '❌ Missing'}")

# Test the embeddings function with a simple text
try:
    print("\n🧪 Testing embeddings generation...")
    test_embeddings = generate_embeddings(azure_openai_client, "This is a test sentence for embedding generation.")
    print(f"✅ Embeddings test successful! Vector dimension: {len(test_embeddings)}")
except Exception as e:
    print(f"❌ Embeddings test failed: {e}")
    print("Please check your Azure OpenAI configuration and try again.")
# Out:
# 🔍 Environment Variables Check:
#    COSMOS_DB_CONNECTION_STRING: ✅ Set
#    DATABASE_NAME: makdb
#    CONTAINER_NAME: makcontainer
#    AZURE_OPENAI_ENDPOINT: https://semantic-aifoundry.services.ai.azure.com/api/projects/firstProject
#    AZURE_OPENAI_KEY: ✅ Set
#    EMBEDDING_ENGINE: text-embedding-ada-002
#    GPT_ENGINE: gpt-4o
#
# 🧪 Testing embeddings generation...
# ✅ Embeddings test successful! Vector dimension: 1536
# ✅ Embeddings test successful! Vector dimension: 1536

# %%
import json
import uuid
import time
from typing import List, Dict

file_path = "./food_items.json"

import os
if not os.path.exists(file_path):
    print(f"File not found: {file_path}")
    print("Please ensure the food_items.json file exists in the current directory")
else:
    print(f"Found data file: {file_path}")

try:
    with open(file_path) as f:
        data = json.load(f)
    
    print(f"📊 Loaded {len(data)} food items")
    
    # Process each item with progress tracking
    success_count = 0
    error_count = 0
    
    for i, obj in enumerate(data):
        try:
            print(f"Processing item {i+1}/{len(data)}: {obj.get('name', 'Unknown')}")
            
            # Generate unique ID
            guid = str(uuid.uuid4())
            
            # Check if description exists
            if 'description' not in obj or not obj['description']:
                print(f" Skipping item {i+1}: No description found")
                continue
            
            # Generate vector embeddings
            vector_embeddings = generate_embeddings(azure_openai_client, obj['description'])
            
            # Add vector and ID to the object
            obj['vector'] = vector_embeddings
            obj['id'] = guid
            
            # Upsert to Cosmos DB
            container.upsert_item(obj)
            
            success_count += 1
            print(f"✅ Successfully processed item {i+1}")
            
            # Add small delay to avoid rate limiting
            time.sleep(0.1)
            
        except Exception as e:
            error_count += 1
            print(f"❌ Error processing item {i+1}: {e}")
            # Continue with next item instead of stopping
            continue
    
    # Save updated dataset
    try:
        with open("./new_dataset.json", 'w') as f:
            json.dump(data, f, indent=2)
        print(f"💾 Saved updated dataset to new_dataset.json")
    except Exception as e:
        print(f"⚠️ Could not save dataset: {e}")
    
    # Summary
    print(f"\n📈 Processing Summary:")
    print(f"   ✅ Successful: {success_count}")
    print(f"   ❌ Errors: {error_count}")
    print(f"   📋 Total: {len(data)}")
    
except FileNotFoundError:
    print(f"❌ Could not find file: {file_path}")
except json.JSONDecodeError as e:
    print(f"❌ Invalid JSON in file: {e}")
except Exception as e:
    print(f"❌ Unexpected error: {e}")
    raise e
# Out:
# Found data file: ./food_items.json
# 📊 Loaded 151 food items
# Processing item 1/151: Ashunti`Way Smoothie
# ✅ Successfully processed item 1
# Processing item 2/151: Jimmy Jam Smoothie
# ✅ Successfully processed item 1
# Processing item 2/151: Jimmy Jam Smoothie
# ✅ Successfully processed item 2
# Processing item 3/151: Tejay Impact Smoothie
# ✅ Successfully processed item 2
# Processing item 3/151: Tejay Impact Smoothie
# ✅ Successfully processed item 3
# Processing item 4/151: Dayton 500 Smoothie
# ✅ Successfully processed item 3
# Processing item 4/151: Dayton 500 Smoothie
# ✅ Successfully processed item 4
# Processing item 5/151: Nappy Head Truth Smoothie
# ✅ Successfully processed item 4
# Processing item 5/151: Nappy Head Truth Smoothie
# ✅ Successfully processed item 5
# Processing item 6/151: Aw Shuckie Shuckie Now Smoothie
# ✅ Successfully processed item 5
# Processing item 6/151: Aw Shuckie Shuckie Now Smoothie
# ✅ Successfully processed item 6
# Processing item 7/151: Early Birds Get the Worm Smoothie
# ✅ Successfully processed item 6
# Processing item 7/151: Early Birds Get the Worm Smoothie
# ✅ Successfully processed item 7
# Processing item 8/151: Jameria Crush Smoothie
# ✅ Successfully processed item 7
# Processing item 8/151: Jameria Crush Smoothie
# ✅ Successfully processed item 8
# Processing item 9/151: Tongue Teaser Smoothie
# ✅ Successfully processed item 8
# Processing item 9/151: Tongue Teaser Smoothie
# ✅ Successfully processed item 9
# Processing item 10/151: Groovy Louie Smoothie
# ✅ Successfully processed item 9
# Processing item 10/151: Groovy Louie Smoothie
# ✅ Successfully processed item 10
# Processing item 11/151: J Wit Da Weezy Smoothie
# ✅ Successfully processed item 10
# Processing item 11/151: J Wit Da Weezy Smoothie
# ✅ Successfully processed item 11
# Processing item 12/151: Dance Wit Ginger Smoothie
# ✅ Successfully processed item 11
# Processing item 12/151: Dance Wit Ginger Smoothie
# ✅ Successfully processed item 12
# Processing item 13/151: Taste on Da Tongue Smoothie
# ✅ Successfully processed item 12
# Processing item 13/151: Taste on Da Tongue Smoothie
# ✅ Successfully processed item 13
# Processing item 14/151: Summer Time Smoothie
# ✅ Successfully processed item 13
# Processing item 14/151: Summer Time Smoothie
# ✅ Successfully processed item 14
# Processing item 15/151: K Blend Smoothie
# ✅ Successfully processed item 14
# Processing item 15/151: K Blend Smoothie
# ✅ Successfully processed item 15
# Processing item 16/151: Green Boi
# ✅ Successfully processed item 15
# Processing item 16/151: Green Boi
# ✅ Successfully processed item 16
# Processing item 17/151: Go Getter
# ✅ Successfully processed item 16
# Processing item 17/151: Go Getter
# ✅ Successfully processed item 17
# Processing item 18/151: Cherry Smash
# ✅ Successfully processed item 17
# Processing item 18/151: Cherry Smash
# ✅ Successfully processed item 18
# Processing item 19/151: Waffle Omelets
# ✅ Successfully processed item 18
# Processing item 19/151: Waffle Omelets
# ✅ Successfully processed item 19
# Processing item 20/151: Chicken Waffle Sandwich
# ✅ Successfully processed item 19
# Processing item 20/151: Chicken Waffle Sandwich
# ✅ Successfully processed item 20
# Processing item 21/151: Kings Hawaiian
# ✅ Successfully processed item 20
# Processing item 21/151: Kings Hawaiian
# ✅ Successfully processed item 21
# Processing item 22/151: Cuban
# ✅ Successfully processed item 21
# Processing item 22/151: Cuban
# ✅ Successfully processed item 22
# Processing item 23/151: Italian
# ✅ Successfully processed item 22
# Processing item 23/151: Italian
# ✅ Successfully processed item 23
# Processing item 24/151: Club Salad
# ✅ Successfully processed item 23
# Processing item 24/151: Club Salad
# ✅ Successfully processed item 24
# Processing item 25/151: Mediterranean  Salad
# ✅ Successfully processed item 24
# Processing item 25/151: Mediterranean  Salad
# ✅ Successfully processed item 25
# Processing item 26/151: Cobb Salad
# ✅ Successfully processed item 25
# Processing item 26/151: Cobb Salad
# ✅ Successfully processed item 26
# Processing item 27/151: House Salad - house dressing
# ✅ Successfully processed item 26
# Processing item 27/151: House Salad - house dressing
# ✅ Successfully processed item 27
# Processing item 28/151: Tabouli Salad
# ✅ Successfully processed item 27
# Processing item 28/151: Tabouli Salad
# ✅ Successfully processed item 28
# Processing item 29/151: Chicken Fattoush
# ✅ Successfully processed item 28
# Processing item 29/151: Chicken Fattoush
# ✅ Successfully processed item 29
# Processing item 30/151: The Greenhouse Salad
# ✅ Successfully processed item 29
# Processing item 30/151: The Greenhouse Salad
# ✅ Successfully processed item 30
# Processing item 31/151: Pretty Good #1
# ✅ Successfully processed item 30
# Processing item 31/151: Pretty Good #1
# ✅ Successfully processed item 31
# Processing item 32/151: GH Cobb Salad
# ✅ Successfully processed item 31
# Processing item 32/151: GH Cobb Salad
# ✅ Successfully processed item 32
# Processing item 33/151: The Freek Salad
# ✅ Successfully processed item 32
# Processing item 33/151: The Freek Salad
# ✅ Successfully processed item 33
# Processing item 34/151: Spring Salad
# ✅ Successfully processed item 33
# Processing item 34/151: Spring Salad
# ✅ Successfully processed item 34
# Processing item 35/151: Buffalo Chicken Salad
# ✅ Successfully processed item 34
# Processing item 35/151: Buffalo Chicken Salad
# ✅ Successfully processed item 35
# Processing item 36/151: Chef Salad
# ✅ Successfully processed item 35
# Processing item 36/151: Chef Salad
# ✅ Successfully processed item 36
# Processing item 37/151: Spinach Salad
# ✅ Successfully processed item 36
# Processing item 37/151: Spinach Salad
# ✅ Successfully processed item 37
# Processing item 38/151: Grilled Sirloin Tip Garden Salad
# ✅ Successfully processed item 37
# Processing item 38/151: Grilled Sirloin Tip Garden Salad
# ✅ Successfully processed item 38
# Processing item 39/151: Grilled Chicken Garden Salad
# ✅ Successfully processed item 38
# Processing item 39/151: Grilled Chicken Garden Salad
# ✅ Successfully processed item 39
# Processing item 40/151: Hamachi Fig
# ✅ Successfully processed item 39
# Processing item 40/151: Hamachi Fig
# ✅ Successfully processed item 40
# Processing item 41/151: Maguro Ringo
# ✅ Successfully processed item 40
# Processing item 41/151: Maguro Ringo
# ✅ Successfully processed item 41
# Processing item 42/151: Nikko
# ✅ Successfully processed item 41
# Processing item 42/151: Nikko
# ✅ Successfully processed item 42
# Processing item 43/151: Beef Udon Noodle Soup
# ✅ Successfully processed item 42
# Processing item 43/151: Beef Udon Noodle Soup
# ✅ Successfully processed item 43
# Processing item 44/151: Shrimp Tempura Udon Noodle Soup
# ✅ Successfully processed item 43
# Processing item 44/151: Shrimp Tempura Udon Noodle Soup
# ✅ Successfully processed item 44
# Processing item 45/151: Hatsu
# ✅ Successfully processed item 44
# Processing item 45/151: Hatsu
# ✅ Successfully processed item 45
# Processing item 46/151: Ginger Albacore
# ✅ Successfully processed item 45
# Processing item 46/151: Ginger Albacore
# ✅ Successfully processed item 46
# Processing item 47/151: 205 Roll
# ✅ Successfully processed item 46
# Processing item 47/151: 205 Roll
# ✅ Successfully processed item 47
# Processing item 48/151: Bender Roll
# ✅ Successfully processed item 47
# Processing item 48/151: Bender Roll
# ✅ Successfully processed item 48
# Processing item 49/151: Buffalo Roll
# ✅ Successfully processed item 48
# Processing item 49/151: Buffalo Roll
# ✅ Successfully processed item 49
# Processing item 50/151: Caipirinha Roll
# ✅ Successfully processed item 49
# Processing item 50/151: Caipirinha Roll
# ✅ Successfully processed item 50
# Processing item 51/151: Cash Me Out Roll
# ✅ Successfully processed item 50
# Processing item 51/151: Cash Me Out Roll
# ✅ Successfully processed item 51
# Processing item 52/151: Double Trouble Roll
# ✅ Successfully processed item 51
# Processing item 52/151: Double Trouble Roll
# ✅ Successfully processed item 52
# Processing item 53/151: H2 Roll
# ✅ Successfully processed item 52
# Processing item 53/151: H2 Roll
# ✅ Successfully processed item 53
# Processing item 54/151: Jumanji Roll
# ✅ Successfully processed item 53
# Processing item 54/151: Jumanji Roll
# ✅ Successfully processed item 54
# Processing item 55/151: Lakeview Roll
# ✅ Successfully processed item 54
# Processing item 55/151: Lakeview Roll
# ✅ Successfully processed item 55
# Processing item 56/151: Last Call Roll
# ✅ Successfully processed item 55
# Processing item 56/151: Last Call Roll
# ✅ Successfully processed item 56
# Processing item 57/151: Open Tab Roll
# ✅ Successfully processed item 56
# Processing item 57/151: Open Tab Roll
# ✅ Successfully processed item 57
# Processing item 58/151: Robin Roll
# ✅ Successfully processed item 57
# Processing item 58/151: Robin Roll
# ✅ Successfully processed item 58
# Processing item 59/151: The Hangover Roll
# ✅ Successfully processed item 58
# Processing item 59/151: The Hangover Roll
# ✅ Successfully processed item 59
# Processing item 60/151: The Welden Roll
# ✅ Successfully processed item 59
# Processing item 60/151: The Welden Roll
# ✅ Successfully processed item 60
# Processing item 61/151: UMAMI Roll
# ✅ Successfully processed item 60
# Processing item 61/151: UMAMI Roll
# ✅ Successfully processed item 61
# Processing item 62/151: Volcano Roll
# ✅ Successfully processed item 61
# Processing item 62/151: Volcano Roll
# ✅ Successfully processed item 62
# Processing item 63/151: W.T.F Roll
# ✅ Successfully processed item 62
# Processing item 63/151: W.T.F Roll
# ✅ Successfully processed item 63
# Processing item 64/151: California Roll
# ✅ Successfully processed item 63
# Processing item 64/151: California Roll
# ✅ Successfully processed item 64
# Processing item 65/151: The Giant Fish Sandwich and Side
# ✅ Successfully processed item 64
# Processing item 65/151: The Giant Fish Sandwich and Side
# ✅ Successfully processed item 65
# Processing item 66/151: NEW The Signature Take Chicken Sandwich
# ✅ Successfully processed item 65
# Processing item 66/151: NEW The Signature Take Chicken Sandwich
# ✅ Successfully processed item 66
# Processing item 67/151: NEW The Spicy Take Chicken Sandwich
# ✅ Successfully processed item 66
# Processing item 67/151: NEW The Spicy Take Chicken Sandwich
# ✅ Successfully processed item 67
# Processing item 68/151: Toasted Frontega Chicken
# ✅ Successfully processed item 67
# Processing item 68/151: Toasted Frontega Chicken
# ✅ Successfully processed item 68
# Processing item 69/151: Bacon Turkey Bravo Sandwich
# ✅ Successfully processed item 68
# Processing item 69/151: Bacon Turkey Bravo Sandwich
# ✅ Successfully processed item 69
# Processing item 70/151: Classic Grilled Cheese Sandwich
# ✅ Successfully processed item 69
# Processing item 70/151: Classic Grilled Cheese Sandwich
# ✅ Successfully processed item 70
# Processing item 71/151: Smokehouse BBQ Chicken Sandwich
# ✅ Successfully processed item 70
# Processing item 71/151: Smokehouse BBQ Chicken Sandwich
# ✅ Successfully processed item 71
# Processing item 72/151: Napa Almond Chicken Salad Sandwich
# ✅ Successfully processed item 71
# Processing item 72/151: Napa Almond Chicken Salad Sandwich
# ✅ Successfully processed item 72
# Processing item 73/151: Tuna Salad Sandwich
# ✅ Successfully processed item 72
# Processing item 73/151: Tuna Salad Sandwich
# ✅ Successfully processed item 73
# Processing item 74/151: Deli Turkey Sandwich
# ✅ Successfully processed item 73
# Processing item 74/151: Deli Turkey Sandwich
# ✅ Successfully processed item 74
# Processing item 75/151: Family Feast with Cookies
# ✅ Successfully processed item 74
# Processing item 75/151: Family Feast with Cookies
# ✅ Successfully processed item 75
# Processing item 76/151: Family Feast
# ✅ Successfully processed item 75
# Processing item 76/151: Family Feast
# ✅ Successfully processed item 76
# Processing item 77/151: Premium Family Feast with Cookies
# ✅ Successfully processed item 76
# Processing item 77/151: Premium Family Feast with Cookies
# ✅ Successfully processed item 77
# Processing item 78/151: Premium Family Feast
# ✅ Successfully processed item 77
# Processing item 78/151: Premium Family Feast
# ✅ Successfully processed item 78
# Processing item 79/151: Golden Temple Sandwich
# ✅ Successfully processed item 78
# Processing item 79/151: Golden Temple Sandwich
# ✅ Successfully processed item 79
# Processing item 80/151: Beyond Burger
# ✅ Successfully processed item 79
# Processing item 80/151: Beyond Burger
# ✅ Successfully processed item 80
# Processing item 81/151: Boca Chik'n Sandwich
# ✅ Successfully processed item 80
# Processing item 81/151: Boca Chik'n Sandwich
# ✅ Successfully processed item 81
# Processing item 82/151: Guacamole Sandwich
# ✅ Successfully processed item 81
# Processing item 82/151: Guacamole Sandwich
# ✅ Successfully processed item 82
# Processing item 83/151: Hummus Sandwich
# ✅ Successfully processed item 82
# Processing item 83/151: Hummus Sandwich
# ✅ Successfully processed item 83
# Processing item 84/151: Tofu Salad Sandwich
# ✅ Successfully processed item 83
# Processing item 84/151: Tofu Salad Sandwich
# ✅ Successfully processed item 84
# Processing item 85/151: Caramelized Jamun and Rabdi
# ✅ Successfully processed item 84
# Processing item 85/151: Caramelized Jamun and Rabdi
# ✅ Successfully processed item 85
# Processing item 86/151: Kulfi
# ✅ Successfully processed item 85
# Processing item 86/151: Kulfi
# ✅ Successfully processed item 86
# Processing item 87/151: Unicorn Churros
# ✅ Successfully processed item 86
# Processing item 87/151: Unicorn Churros
# ✅ Successfully processed item 87
# Processing item 88/151: Cotton Candy
# ✅ Successfully processed item 87
# Processing item 88/151: Cotton Candy
# ✅ Successfully processed item 88
# Processing item 89/151: Banana Burrito
# ✅ Successfully processed item 88
# Processing item 89/151: Banana Burrito
# ✅ Successfully processed item 89
# Processing item 90/151: Apple Crisp
# ✅ Successfully processed item 89
# Processing item 90/151: Apple Crisp
# ✅ Successfully processed item 90
# Processing item 91/151: Fried Cheesecake
# ✅ Successfully processed item 90
# Processing item 91/151: Fried Cheesecake
# ✅ Successfully processed item 91
# Processing item 92/151: Signature Panookie
# ✅ Successfully processed item 91
# Processing item 92/151: Signature Panookie
# ✅ Successfully processed item 92
# Processing item 93/151: New Double Cobblers
# ✅ Successfully processed item 92
# Processing item 93/151: New Double Cobblers
# ✅ Successfully processed item 93
# Processing item 94/151: Strawberry Cheesecake
# ✅ Successfully processed item 93
# Processing item 94/151: Strawberry Cheesecake
# ✅ Successfully processed item 94
# Processing item 95/151: French Silk Pie - Slice
# ✅ Successfully processed item 94
# Processing item 95/151: French Silk Pie - Slice
# ✅ Successfully processed item 95
# Processing item 96/151: Key Lime Pie - Slice
# ✅ Successfully processed item 95
# Processing item 96/151: Key Lime Pie - Slice
# ✅ Successfully processed item 96
# Processing item 97/151: Brownie Lover's Sundae for Two
# ✅ Successfully processed item 96
# Processing item 97/151: Brownie Lover's Sundae for Two
# ✅ Successfully processed item 97
# Processing item 98/151: Whole French Silk Pie
# ✅ Successfully processed item 97
# Processing item 98/151: Whole French Silk Pie
# ✅ Successfully processed item 98
# Processing item 99/151: Whole Key Lime Pie
# ✅ Successfully processed item 98
# Processing item 99/151: Whole Key Lime Pie
# ✅ Successfully processed item 99
# Processing item 100/151: Fresh Baked Cookies
# ✅ Successfully processed item 99
# Processing item 100/151: Fresh Baked Cookies
# ✅ Successfully processed item 100
# Processing item 101/151: NEW Citrus Asian Crunch Salad with Chicken
# ✅ Successfully processed item 100
# Processing item 101/151: NEW Citrus Asian Crunch Salad with Chicken
# ✅ Successfully processed item 101
# Processing item 102/151: Green Goddess Cobb Salad with Chicken
# ✅ Successfully processed item 101
# Processing item 102/151: Green Goddess Cobb Salad with Chicken
# ✅ Successfully processed item 102
# Processing item 103/151: Fuji Apple Salad with Chicken
# ✅ Successfully processed item 102
# Processing item 103/151: Fuji Apple Salad with Chicken
# ✅ Successfully processed item 103
# Processing item 104/151: Caesar Salad with Chicken
# ✅ Successfully processed item 103
# Processing item 104/151: Caesar Salad with Chicken
# ✅ Successfully processed item 104
# Processing item 105/151: Asian Sesame Salad with Chicken
# ✅ Successfully processed item 104
# Processing item 105/151: Asian Sesame Salad with Chicken
# ✅ Successfully processed item 105
# Processing item 106/151: BBQ Chicken Salad
# ✅ Successfully processed item 105
# Processing item 106/151: BBQ Chicken Salad
# ✅ Successfully processed item 106
# Processing item 107/151: Caesar Salad
# ✅ Successfully processed item 106
# Processing item 107/151: Caesar Salad
# ✅ Successfully processed item 107
# Processing item 108/151: Golden Temple Salad
# ✅ Successfully processed item 107
# Processing item 108/151: Golden Temple Salad
# ✅ Successfully processed item 108
# Processing item 109/151: Veggie Salad
# ✅ Successfully processed item 108
# Processing item 109/151: Veggie Salad
# ✅ Successfully processed item 109
# Processing item 110/151: Italian Grilled Chicken Salad
# ✅ Successfully processed item 109
# Processing item 110/151: Italian Grilled Chicken Salad
# ✅ Successfully processed item 110
# Processing item 111/151: The Roman Empire Salad
# ✅ Successfully processed item 110
# Processing item 111/151: The Roman Empire Salad
# ✅ Successfully processed item 111
# Processing item 112/151: Goomar Salad
# ✅ Successfully processed item 111
# Processing item 112/151: Goomar Salad
# ✅ Successfully processed item 112
# Processing item 113/151: Upstream Salad
# ✅ Successfully processed item 112
# Processing item 113/151: Upstream Salad
# ✅ Successfully processed item 113
# Processing item 114/151: Goat in the Orchard
# ✅ Successfully processed item 113
# Processing item 114/151: Goat in the Orchard
# ✅ Successfully processed item 114
# Processing item 115/151: Makarios Salad
# ✅ Successfully processed item 114
# Processing item 115/151: Makarios Salad
# ✅ Successfully processed item 115
# Processing item 116/151: Taco Salad
# ✅ Successfully processed item 115
# Processing item 116/151: Taco Salad
# ✅ Successfully processed item 116
# Processing item 117/151: Chicken Salad
# ✅ Successfully processed item 116
# Processing item 117/151: Chicken Salad
# ✅ Successfully processed item 117
# Processing item 118/151: Shrimp Salad
# ✅ Successfully processed item 117
# Processing item 118/151: Shrimp Salad
# ✅ Successfully processed item 118
# Processing item 119/151: Gourmet Vegetarian Pizza
# ✅ Successfully processed item 118
# Processing item 119/151: Gourmet Vegetarian Pizza
# ✅ Successfully processed item 119
# Processing item 120/151: Cheese Pizza
# ✅ Successfully processed item 119
# Processing item 120/151: Cheese Pizza
# ✅ Successfully processed item 120
# Processing item 121/151: Double Slice Cheese Pizza
# ✅ Successfully processed item 120
# Processing item 121/151: Double Slice Cheese Pizza
# ✅ Successfully processed item 121
# Processing item 122/151: Double Slice Pepperoni Pizza
# ✅ Successfully processed item 121
# Processing item 122/151: Double Slice Pepperoni Pizza
# ✅ Successfully processed item 122
# Processing item 123/151: Iced 100% Colombian Dark Roast
# ✅ Successfully processed item 122
# Processing item 123/151: Iced 100% Colombian Dark Roast
# ✅ Successfully processed item 123
# Processing item 124/151: Hazelnut Coffee
# ✅ Successfully processed item 123
# Processing item 124/151: Hazelnut Coffee
# ✅ Successfully processed item 124
# Processing item 125/151: 100% Colombian Dark Roast Coffee
# ✅ Successfully processed item 124
# Processing item 125/151: 100% Colombian Dark Roast Coffee
# ✅ Successfully processed item 125
# Processing item 126/151: Cafe Blend Light Roast
# ✅ Successfully processed item 125
# Processing item 126/151: Cafe Blend Light Roast
# ✅ Successfully processed item 126
# Processing item 127/151: Decaf Coffee
# ✅ Successfully processed item 126
# Processing item 127/151: Decaf Coffee
# ✅ Successfully processed item 127
# Processing item 128/151: Hot Tea
# ✅ Successfully processed item 127
# Processing item 128/151: Hot Tea
# ✅ Successfully processed item 128
# Processing item 129/151: Madagascar Vanilla Cream Cold Brew
# ✅ Successfully processed item 128
# Processing item 129/151: Madagascar Vanilla Cream Cold Brew
# ✅ Successfully processed item 129
# Processing item 130/151: Madagascar Vanilla Almond Cold Brew
# ✅ Successfully processed item 129
# Processing item 130/151: Madagascar Vanilla Almond Cold Brew
# ✅ Successfully processed item 130
# Processing item 131/151: Hot Chocolate
# ✅ Successfully processed item 130
# Processing item 131/151: Hot Chocolate
# ✅ Successfully processed item 131
# Processing item 132/151: Hazelnut Coffee Tote
# ✅ Successfully processed item 131
# Processing item 132/151: Hazelnut Coffee Tote
# ✅ Successfully processed item 132
# Processing item 133/151: Cafe Blend Light Roast Coffee Tote
# ✅ Successfully processed item 132
# Processing item 133/151: Cafe Blend Light Roast Coffee Tote
# ✅ Successfully processed item 133
# Processing item 134/151: 100% Colombian Dark Roast Coffee Tote
# ✅ Successfully processed item 133
# Processing item 134/151: 100% Colombian Dark Roast Coffee Tote
# ✅ Successfully processed item 134
# Processing item 135/151: Decaf Coffee Tote
# ✅ Successfully processed item 134
# Processing item 135/151: Decaf Coffee Tote
# ✅ Successfully processed item 135
# Processing item 136/151: Asiago Bagel
# ✅ Successfully processed item 135
# Processing item 136/151: Asiago Bagel
# ✅ Successfully processed item 136
# Processing item 137/151: One Dozen Mixed Cookies
# ✅ Successfully processed item 136
# Processing item 137/151: One Dozen Mixed Cookies
# ✅ Successfully processed item 137
# Processing item 138/151: Madagascar Vanilla Latte
# ✅ Successfully processed item 137
# Processing item 138/151: Madagascar Vanilla Latte
# ✅ Successfully processed item 138
# Processing item 139/151: Chocolate Latte
# ✅ Successfully processed item 138
# Processing item 139/151: Chocolate Latte
# ✅ Successfully processed item 139
# Processing item 140/151: Cappuccino
# ✅ Successfully processed item 139
# Processing item 140/151: Cappuccino
# ✅ Successfully processed item 140
# Processing item 141/151: Americano
# ✅ Successfully processed item 140
# Processing item 141/151: Americano
# ✅ Successfully processed item 141
# Processing item 142/151: Frozen Caramel Cold Brew
# ✅ Successfully processed item 141
# Processing item 142/151: Frozen Caramel Cold Brew
# ✅ Successfully processed item 142
# Processing item 143/151: Spicy Pimento Cheese
# ✅ Successfully processed item 142
# Processing item 143/151: Spicy Pimento Cheese
# ✅ Successfully processed item 143
# Processing item 144/151: Veggie Samosa
# ✅ Successfully processed item 143
# Processing item 144/151: Veggie Samosa
# ✅ Successfully processed item 144
# Processing item 145/151: Crisp Onion Fritters
# ✅ Successfully processed item 144
# Processing item 145/151: Crisp Onion Fritters
# ✅ Successfully processed item 145
# Processing item 146/151: Cauli Manchurian
# ✅ Successfully processed item 145
# Processing item 146/151: Cauli Manchurian
# ✅ Successfully processed item 146
# Processing item 147/151: Cottage Cheese Tikka
# ✅ Successfully processed item 146
# Processing item 147/151: Cottage Cheese Tikka
# ✅ Successfully processed item 147
# Processing item 148/151: Peasant Garlic Soup
# ✅ Successfully processed item 147
# Processing item 148/151: Peasant Garlic Soup
# ✅ Successfully processed item 148
# Processing item 149/151: Appetizer Platter (for 2)
# ✅ Successfully processed item 148
# Processing item 149/151: Appetizer Platter (for 2)
# ✅ Successfully processed item 149
# Processing item 150/151: Appetizer Platter for 2
# ✅ Successfully processed item 149
# Processing item 150/151: Appetizer Platter for 2
# ✅ Successfully processed item 150
# Processing item 151/151: Pu Pu Platter
# ✅ Successfully processed item 150
# Processing item 151/151: Pu Pu Platter
# ✅ Successfully processed item 151
# ✅ Successfully processed item 151
# 💾 Saved updated dataset to new_dataset.json
#
# 📈 Processing Summary:
#    ✅ Successful: 151
#    ❌ Errors: 0
#    📋 Total: 151
# 💾 Saved updated dataset to new_dataset.json
#
# 📈 Processing Summary:
#    ✅ Successful: 151
#    ❌ Errors: 0
#    📋 Total: 151

# %% [markdown]
# ### Generating vector embeddings for the user query

# %%
user_query="Are there any food that is high in protein"
user_embeddings = generate_embeddings(azure_openai_client, user_query)
print(user_embeddings)
# Out:
# [0.003758044680580497, -0.029371747747063637, -0.02819174714386463, -0.015532395802438259, 0.01287098228931427, 0.008542176336050034, -0.014762830920517445, -0.022355876863002777, -0.03168044611811638, -0.006143697537481785, 0.02696044370532036, 0.02248413674533367, 0.010741851292550564, 0.0010052449069917202, -0.011395981535315514, 0.013980438932776451, 0.04853392764925957, 0.002608506241813302, 0.012627286836504936, -0.01421130821108818, -0.010049242526292801, 0.009420763701200485, 0.02778131328523159, -0.020406311377882957, 0.008048372343182564, 0.013287830166518688, 0.004954077769070864, -0.025241747498512268, 0.009388698264956474, -0.008728154934942722, 0.049046970903873444, 0.004460273310542107, -0.01968804933130741, 0.004604566376656294, -0.008625546470284462, 0.01154348161071539, -0.00991456862539053, 0.027088703587651253, 0.034168705344200134, 0.0060090236365795135, 0.026601312682032585, 0.0015711961314082146, 0.012794025242328644, 0.009658046066761017, -0.02283044159412384, 0.0021980712190270424, -0.001406861818395555, 0.033706966787576675, -0.007439132779836655, -0.003262636950239539, 0.018905658274888992, -0.008099676109850407, -0.013736743479967117, -0.013518699444830418, 0.00024990836391225457, -0.0024337507784366608, 0.00449233828112483, 0.00949130766093731, 0.0069517414085567, -0.013634135015308857, 0.01575043983757496, 0.0019816309213638306, 0.0024209246039390564, -0.006881197914481163, -0.01060076430439949, 0.017982179298996925, -0.014775657095015049, 0.0013763998867943883, -0.01811044104397297, 0.004649457987397909, 0.01991891860961914, 0.038888707756996155, -0.029859138652682304, -0.015224569477140903, 0.002579647582024336, -0.005194566678255796, -0.018366962671279907, 0.009831198491156101, -0.004020979627966881, -0.02696044370532036, 0.01813609153032303, -0.013172395527362823, 0.012736308388411999, -0.007362176198512316, 0.02993609569966793, -0.034579139202833176, -0.007785437162965536, 0.014224134385585785, 0.0006741713732481003, -0.01866196282207966, 0.02585739828646183, 0.015327178873121738, 0.007169784978032112, 0.0035143489949405193, -0.046661317348480225, 0.023510225117206573, 0.003190490184351802, 0.023279353976249695, -0.014865439385175705, 0.011447286233305931, -0.013127503916621208, 0.006422664970159531, -0.015378482639789581, -0.010632829740643501, -0.01076109055429697, 0.017315221950411797, 0.01051098108291626, 0.0029980987310409546, -5.631455496768467e-05, -0.02131696231663227, -0.014955221675336361, 0.029012616723775864, 0.02647305093705654, -0.06038523465394974, 0.007221089210361242, -0.000486589822685346, 0.0372726209461689, 0.003421359695494175, 0.005162501707673073, 0.015853047370910645, 0.01705870032310486, -0.0004930028808303177, 0.03537435829639435, -0.015519569627940655, 0.017481962218880653, 0.022933050990104675, 0.0010517394402995706, -0.018187396228313446, -0.004085110034793615, -0.00390875106677413, 0.03275783732533455, 0.0004260667192284018, 0.0033027182798832655, -0.0016641853144392371, -0.0031407889910042286, 0.018880005925893784, -0.01941870152950287, -0.01231946051120758, -0.0039760880172252655, -0.01898261532187462, 7.184615242294967e-05, 0.04004305601119995, -0.017302395775914192, 0.005181740503758192, -0.03014131262898445, 0.006797828245908022, 0.024792833253741264, 0.01281326450407505, -0.00204896810464561, -0.00331554445438087, 0.0057653277181088924, -0.002000870183110237, 0.0317317470908165, -8.206693746615201e-05, 0.0019367396598681808, 0.025036528706550598, -0.014634570106863976, 0.003921577241271734, -0.022137831896543503, -0.0034117400646209717, -0.004203751217573881, -0.022958703339099884, 0.027858268469572067, -0.008965437300503254, 0.00393760995939374, 0.02521609514951706, 0.04035088047385216, -0.005085545126348734, -0.015237395651638508, 0.017828267067670822, -0.014916744083166122, 0.019444353878498077, -0.025036528706550598, 0.014147178269922733, -0.003706740215420723, -0.00850369781255722, -0.0036618488375097513, -0.0007960192742757499, -0.016699571162462234,  ...

# %% [markdown]
# ### Sending a query to database with filtering based upon VectorDistance

# %%
queryText = f""" SELECT TOP 5 c.category, c.name, c.description, c.price, VectorDistance(c.vector, {user_embeddings}) AS SimilarityScore
FROM c
ORDER BY VectorDistance(c.vector, {user_embeddings})"""
results = container.query_items(
    query=queryText,
    enable_cross_partition_query=True
)
dishes = []

for item in results:
    print(item)
    dishes.append(item)
# Out:
# {'category': 'Smoothies', 'name': 'Go Getter', 'description': 'banana, peanut butter, raw cacao, cinnamon, hemp seeds, walnuts, almond milk, chocolate vegan protein', 'price': '10.8 USD', 'SimilarityScore': 0.8253558126946419}
# {'category': 'Smoothies', 'name': 'Go Getter', 'description': 'banana, peanut butter, raw cacao, cinnamon, hemp seeds, walnuts, almond milk, chocolate vegan protein', 'price': '10.8 USD', 'SimilarityScore': 0.8253558126946419}
# {'category': 'Smoothies', 'name': 'K Blend Smoothie', 'description': 'Mango, pineapple, peaches pear apricot, cranberry, lemons, lemonade, flaxseeds, and strawberry protein. Our fruity tasty smoothies are blended to perfection.', 'price': '8.49 USD', 'SimilarityScore': 0.8198624605491195}
# {'category': 'Smoothies', 'name': 'K Blend Smoothie', 'description': 'Mango, pineapple, peaches pear apricot, cranberry, lemons, lemonade, flaxseeds, and strawberry protein. Our fruity tasty smoothies are blended to perfection.', 'price': '8.49 USD', 'SimilarityScore': 0.8198624605491195}
# {'category': 'Smoothies', 'name': 'Green Boi', 'description': 'Banana, strawberry, spinach, yogurt, flax, collagen, ashwagandha, spirulina, and agave. With muscles.', 'price': '10.0 USD', 'SimilarityScore': 0.8109125363001061}

# %% [markdown]
# ### Sending call to our GPT engine for summarisation

# %%
system_message = f"""You are meant to behave as a RAG chatbot that derives its context from a database of food items stored in azure cosmosDB for noSQL API.
please asnwer strictly from the context from the database provided and if you dont have an answer please politely say so. dont include any extra 
information that is not in the context and dont include links as well.
the context passed to you will be in the form of a pythonic list with each object in the list containing details of a food item and
having structure as follows:

 "category": "the category of the food item like smoothies, burgers, etc",
 "name": "the name of the food item",
 "description": "the description of the food item",
"price": "the price of the food item in USD",


the pythonic list contains best 5 matches to the user query based on cosine similarity of the embeddings of the user query and the food item descriptions.
please structure your answers in a very professional manner and in such a way that the user does not get to know that its RAG working under the hood
and its as if they are talking to a human."""

user_message = f""" the user query is: {user_query}
the context is : {dishes}"""

chat_completions_response = azure_openai_client.chat.completions.create(
    model = os.getenv("GPT_ENGINE"),
    messages = [
        {"role": "system", "content": system_message},
        {"role": "user", "content": user_message}
    ],
    temperature=0.7
)

print(chat_completions_response.choices[0].message.content)
# Out:
# Certainly! Based on your query, here are some options that are high in protein:
#
# 1. **Go Getter (Smoothie)**
#    - **Description**: A blend of banana, peanut butter, raw cacao, cinnamon, hemp seeds, walnuts, almond milk, and chocolate vegan protein.
#    - **Price**: 10.8 USD
#
# 2. **K Blend Smoothie**
#    - **Description**: A fruity mix of mango, pineapple, peaches, pear, apricot, cranberry, lemons, lemonade, flaxseeds, and strawberry protein. Blended to perfection for a tasty and nutritious experience.
#    - **Price**: 8.49 USD
#
# 3. **Green Boi (Smoothie)**
#    - **Description**: A nutrient-rich combination of banana, strawberry, spinach, yogurt, flax, collagen, ashwagandha, spirulina, and agave. Designed to support strength and vitality.
#    - **Price**: 10.0 USD
#
# These smoothies are excellent choices for a protein boost! Let me know if you need further assistance.
